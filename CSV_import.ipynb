# %%
import Pkg; Pkg.add("CSV")
import Pkg; Pkg.add("DataFrames")
using CSV, DataFrames
test = DataFrame(CSV.File("C://Users//r1ryo//DataspellProjects//Python//GCI//Home-Credit-Default-Risk//test.csv"))
# Out:
#     Updating registry at `C:\Users\r1ryo\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed SentinelArrays ───── v1.3.16
#    Installed WorkerUtilities ──── v1.6.1
#    Installed WeakRefStrings ───── v1.4.2
#    Installed PooledArrays ─────── v1.4.2
#    Installed InlineStrings ────── v1.3.2
#    Installed FilePathsBase ────── v0.9.20
#    Installed TranscodingStreams ─ v0.9.10
#    Installed CodecZlib ────────── v0.7.0
#    Installed CSV ──────────────── v0.10.8
#     Updating `C:\Users\r1ryo\.julia\environments\v1.8\Project.toml`
#   [336ed68f] + CSV v0.10.8
#     Updating `C:\Users\r1ryo\.julia\environments\v1.8\Manifest.toml`
#   [336ed68f] + CSV v0.10.8
#   [944b1d66] + CodecZlib v0.7.0
#   [48062228] + FilePathsBase v0.9.20
#   [842dd82b] + InlineStrings v1.3.2
#   [2dfb63ee] + PooledArrays v1.4.2
#   [91c51154] + SentinelArrays v1.3.16
#   [3bb67fe8] + TranscodingStreams v0.9.10
#   [ea10d353] + WeakRefStrings v1.4.2
# ...

# %%
test[:, 2]
# Out:
# 61500-element PooledArrays.PooledVector{String15, UInt32, Vector{UInt32}}:
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Revolving loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  ⋮
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"
#  "Cash loans"

# %%
import Pkg; Pkg.add("Lathe")
using Lathe
scaled_feature = Lathe.preprocess.OneHotEncode(iris, :variety)

# %%
Σ(x, y) = x + y
# Out:
# Σ (generic function with 1 method)

# %%
Σ(3234,3245)
# Out:
# 6479

# %%
typeof(
	[
	2 4 
	5 2
	])
# Out:
# Matrix{Int64} (alias for Array{Int64, 2})
